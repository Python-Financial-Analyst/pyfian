# %% [markdown]
# <a href="https://colab.research.google.com/github/Python-Financial-Analyst/pyfian/blob/main/notebooks/fixed_income/08_bootstrapping.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>

# %% [markdown]
# # Bootstrapping
